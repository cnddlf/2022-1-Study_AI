# %% [markdown]
# #1. 데이터 읽어들이기

# %%
from sklearn.datasets import load_boston

# boston 데이터셋 로드
boston = load_boston()

# %%
import pandas as pd

df_data = pd.DataFrame(boston.data, columns=boston.feature_names)
df_labels = pd.Series(boston.target)

# %%
# 모델 생성
from sklearn.linear_model import Ridge

ridge = Ridge(alpha = 10)

# %%
# 교차 검증
# scoring = neg_mean_squared_error

from sklearn.model_selection import cross_val_score

neg_mse_scores = cross_val_score(ridge, df_data, df_labels, scoring = "neg_mean_squared_error", cv = 5)
neg_mse_scores
# Out:
# array([-11.4217962 , -24.29446706, -28.14355069, -74.59916618,
#        -28.51714218])

# %%
import numpy as np
# RMSE
rmse = np.sqrt(neg_mse_scores)
rmse * -1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([nan, nan, nan, nan, nan])

# %%
# 평균 RMSE
np.mean(rmse) * -1
# Out:
# nan

# %%
def get_best_hyper_parameter(clf, param_grid=params, scoring='accuracy', cv=5):

grid_cv.fit(df_data, df_labels)

# %%
# Ridge에 사용될 alpha 파라미터의 값들을 정의
alpha = [0, 0.1, 1, 10, 100]

# alphas list 값을 iteration하면서 alpha에 따른 평균 rmse 구함
for alpha in alphas : 
  ridge = Ridge(alpha = alpha)

  # cross_val_Score를 이용하여 5 fold의 평균 RMSE 계산
  neg_mse_scores = cross_val_score(ridge, df_data, df_labels, scoring="neg_mean_squared_error", cv=5)
  avg_rmse = np.mean(np.sqrt(-1 * neg_mse_scores))
  print('alpha {0} 일 때 5 folds의 평균 RMSE : {1:.3f}'.format(alpha,avg_rmse))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-39f05612f51d> in <module>()
#       3
#       4 # alphas list 값을 iteration하면서 alpha에 따른 평균 rmse 구함
# ----> 5 for alpha in alphas :
#       6   ridge = Ridge(alpha = alpha)
#       7
#
# NameError: name 'alphas' is not defined

# %%
# 위의 코드를 이용하여 lasso 모델을 생성하시오.
# 모델 생성
from sklearn.linear_model import Lasso

lasso = Lasso(alpha = 10)
