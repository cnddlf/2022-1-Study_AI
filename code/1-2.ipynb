# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

path = '/content/drive/MyDrive/인공지능/data/bicycle.csv'

df = pd.read_csv(path, engine='python', encoding='cp949')
df
# Out:
#          자전거번호              대여일시  대여소번호  ... 반납거치대  이용시간    이용거리
# 0    SPB-23220   2019-11-01 8:48    646  ...   7.0  12.0  1100.0
# 1    SPB-16216   2019-11-04 8:38    646  ...   2.0   7.0  1420.0
# 2    SPB-21097   2019-11-04 8:46    646  ...   7.0  10.0     NaN
# 3    SPB-22292   2019-11-05 8:34    646  ...   NaN  10.0  1380.0
# 4    SPB-07935  2019-11-05 12:29    512  ...   7.0  10.0  1650.0
# ..         ...               ...    ...  ...   ...   ...     ...
# 415  SPB-12116   2019-11-15 4:22    112  ...   1.0  11.0  2200.0
# 416  SPB-17768   2019-11-15 9:31    103  ...   NaN   5.0     NaN
# 417  SPB-18841  2019-11-15 20:40    113  ...   1.0  12.0  2280.0
# 418  SPB-24467  2019-11-15 21:55    152  ...   1.0  10.0  1180.0
# 419  SPB-17570  2019-11-15 22:16    391  ...   5.0  48.0  8100.0
#
# [420 rows x 11 columns]

# %%
df.head()
# Out:
#        자전거번호              대여일시  대여소번호  ... 반납거치대  이용시간    이용거리
# 0  SPB-23220   2019-11-01 8:48    646  ...   7.0  12.0  1100.0
# 1  SPB-16216   2019-11-04 8:38    646  ...   2.0   7.0  1420.0
# 2  SPB-21097   2019-11-04 8:46    646  ...   7.0  10.0  1256.0
# 3  SPB-22292   2019-11-05 8:34    646  ...   NaN  10.0  1380.0
# 4  SPB-07935  2019-11-05 12:29    512  ...   7.0  10.0  1650.0
#
# [5 rows x 11 columns]

# %%
df[df['대여소번호']==646]
# Out:
#         자전거번호             대여일시  대여소번호  ... 반납거치대  이용시간    이용거리
# 0   SPB-23220  2019-11-01 8:48    646  ...   7.0  12.0  1100.0
# 1   SPB-16216  2019-11-04 8:38    646  ...   2.0   7.0  1420.0
# 2   SPB-21097  2019-11-04 8:46    646  ...   7.0  10.0     NaN
# 3   SPB-22292  2019-11-05 8:34    646  ...   NaN  10.0  1380.0
# 5   SPB-18401  2019-11-06 8:52    646  ...   7.0  11.0  1350.0
# 6   SPB-18350  2019-11-06 8:35    646  ...   2.0   9.0  1390.0
# 8   SPB-20220  2019-11-11 8:35    646  ...   2.0   6.0  1160.0
# 9   SPB-20102  2019-11-11 9:45    646  ...   7.0  30.0  1060.0
# 10  SPB-10000  2019-11-12 8:35    646  ...   2.0   8.0  1300.0
# 11  SPB-20145  2019-11-13 8:30    646  ...   2.0   NaN  1060.0
# 12  SPB-19057  2019-11-13 8:55    646  ...   7.0  11.0     NaN
# 13  SPB-19645  2019-11-14 9:44    646  ...   7.0  16.0  1140.0
# 14  SPB-21851  2019-11-14 9:33    646  ...   2.0  28.0  1220.0
# 15  SPB-13973  2019-11-15 8:42    646  ...   2.0   6.0  1370.0
# 16  SPB-22311  2019-11-18 8:32    646  ...   2.0   NaN  1350.0
# 17  SPB-02270  2019-11-18 8:49    646  ...   7.0  11.0  1350.0
# 18  SPB-23659  2019-11-21 8:36    646  ...   2.0   6.0  1130.0
# 19  SPB-23497  2019-11-21 8:50    646  ...   7.0  13.0  1330.0
# 21  SPB-21810  2019-11-25 8:41    646  ...   2.0   7.0  1310.0
# 22  SPB-05857  2019-11-26 8:40    646  ...   2.0   NaN  1380.0
# 24  SPB-20076  2019-11-28 8:37    646  ...   2.0   5.0  1070.0
#
# [21 rows x 11 columns]

# %%
import numpy as np

df2 = df
#df2.replace(np.nan, 'test')

df2.replace({'이용거리':np.nan}, {'이용거리':'test'})
#df2.head
# Out:
#          자전거번호              대여일시  대여소번호  ... 반납거치대  이용시간    이용거리
# 0    SPB-23220   2019-11-01 8:48    646  ...   7.0  12.0  1100.0
# 1    SPB-16216   2019-11-04 8:38    646  ...   2.0   7.0  1420.0
# 2    SPB-21097   2019-11-04 8:46    646  ...   7.0  10.0    test
# 3    SPB-22292   2019-11-05 8:34    646  ...   NaN  10.0  1380.0
# 4    SPB-07935  2019-11-05 12:29    512  ...   7.0  10.0  1650.0
# ..         ...               ...    ...  ...   ...   ...     ...
# 415  SPB-12116   2019-11-15 4:22    112  ...   1.0  11.0  2200.0
# 416  SPB-17768   2019-11-15 9:31    103  ...   NaN   5.0    test
# 417  SPB-18841  2019-11-15 20:40    113  ...   1.0  12.0  2280.0
# 418  SPB-24467  2019-11-15 21:55    152  ...   1.0  10.0  1180.0
# 419  SPB-17570  2019-11-15 22:16    391  ...   5.0  48.0  8100.0
#
# [420 rows x 11 columns]

# %%
# df[df['대여소번호']==646]['이용거리']
mean646 = df2[df2['대여소번호']==112]['이용거리'].mean()
mean646 = round(mean646, 0)
df2[df2['대여소번호']==112] = df2[df2['대여소번호']==112].replace({'이용거리':np.nan}, {'이용거리':mean646})
df2
# Out:
#          자전거번호              대여일시  대여소번호  ... 반납거치대  이용시간    이용거리
# 0    SPB-23220   2019-11-01 8:48    646  ...   7.0  12.0  1100.0
# 1    SPB-16216   2019-11-04 8:38    646  ...   2.0   7.0  1420.0
# 2    SPB-21097   2019-11-04 8:46    646  ...   7.0  10.0  1256.0
# 3    SPB-22292   2019-11-05 8:34    646  ...   NaN  10.0  1380.0
# 4    SPB-07935  2019-11-05 12:29    512  ...   7.0  10.0  1650.0
# ..         ...               ...    ...  ...   ...   ...     ...
# 415  SPB-12116   2019-11-15 4:22    112  ...   1.0  11.0  2200.0
# 416  SPB-17768   2019-11-15 9:31    103  ...   NaN   5.0     NaN
# 417  SPB-18841  2019-11-15 20:40    113  ...   1.0  12.0  2280.0
# 418  SPB-24467  2019-11-15 21:55    152  ...   1.0  10.0  1180.0
# 419  SPB-17570  2019-11-15 22:16    391  ...   5.0  48.0  8100.0
#
# [420 rows x 11 columns]

# %%
def ReplaceNaN(rentNum):
  mean646 = df2[df2['대여소번호']==rentNum]['이용거리'].mean()
  mean646 = round(mean646, 0)
  df2[df2['대여소번호']==112] = df2[df2['대여소번호']==112].replace({'이용거리':np.nan}, {'이용거리':mean646})
  return df2

df3 = ReplaceNaN(103)
df3
# Out:
#          자전거번호              대여일시  대여소번호  ... 반납거치대  이용시간    이용거리
# 0    SPB-23220   2019-11-01 8:48    646  ...   7.0  12.0  1100.0
# 1    SPB-16216   2019-11-04 8:38    646  ...   2.0   7.0  1420.0
# 2    SPB-21097   2019-11-04 8:46    646  ...   7.0  10.0  1256.0
# 3    SPB-22292   2019-11-05 8:34    646  ...   NaN  10.0  1380.0
# 4    SPB-07935  2019-11-05 12:29    512  ...   7.0  10.0  1650.0
# ..         ...               ...    ...  ...   ...   ...     ...
# 415  SPB-12116   2019-11-15 4:22    112  ...   1.0  11.0  2200.0
# 416  SPB-17768   2019-11-15 9:31    103  ...   NaN   5.0     NaN
# 417  SPB-18841  2019-11-15 20:40    113  ...   1.0  12.0  2280.0
# 418  SPB-24467  2019-11-15 21:55    152  ...   1.0  10.0  1180.0
# 419  SPB-17570  2019-11-15 22:16    391  ...   5.0  48.0  8100.0
#
# [420 rows x 11 columns]

# %%
for idx in [646, 112, 103]:
  mean646 = df2[df2['대여소번호']==idx]['이용거리'].mean()
  mean646 = round(mean646, 0)
  df2[df2['대여소번호']==112] = df2[df2['대여소번호']==112].replace({'이용거리':np.nan}, {'이용거리':mean646})
df2
# Out:
#          자전거번호              대여일시  대여소번호  ... 반납거치대  이용시간    이용거리
# 0    SPB-23220   2019-11-01 8:48    646  ...   7.0  12.0  1100.0
# 1    SPB-16216   2019-11-04 8:38    646  ...   2.0   7.0  1420.0
# 2    SPB-21097   2019-11-04 8:46    646  ...   7.0  10.0  1256.0
# 3    SPB-22292   2019-11-05 8:34    646  ...   NaN  10.0  1380.0
# 4    SPB-07935  2019-11-05 12:29    512  ...   7.0  10.0  1650.0
# ..         ...               ...    ...  ...   ...   ...     ...
# 415  SPB-12116   2019-11-15 4:22    112  ...   1.0  11.0  2200.0
# 416  SPB-17768   2019-11-15 9:31    103  ...   NaN   5.0     NaN
# 417  SPB-18841  2019-11-15 20:40    113  ...   1.0  12.0  2280.0
# 418  SPB-24467  2019-11-15 21:55    152  ...   1.0  10.0  1180.0
# 419  SPB-17570  2019-11-15 22:16    391  ...   5.0  48.0  8100.0
#
# [420 rows x 11 columns]

# %%
for idx in [646, 112, 103]:
  df3 = ReplaceNaN(idx)
df3
# Out:
#          자전거번호              대여일시  대여소번호  ... 반납거치대  이용시간    이용거리
# 0    SPB-23220   2019-11-01 8:48    646  ...   7.0  12.0  1100.0
# 1    SPB-16216   2019-11-04 8:38    646  ...   2.0   7.0  1420.0
# 2    SPB-21097   2019-11-04 8:46    646  ...   7.0  10.0  1256.0
# 3    SPB-22292   2019-11-05 8:34    646  ...   NaN  10.0  1380.0
# 4    SPB-07935  2019-11-05 12:29    512  ...   7.0  10.0  1650.0
# ..         ...               ...    ...  ...   ...   ...     ...
# 415  SPB-12116   2019-11-15 4:22    112  ...   1.0  11.0  2200.0
# 416  SPB-17768   2019-11-15 9:31    103  ...   NaN   5.0     NaN
# 417  SPB-18841  2019-11-15 20:40    113  ...   1.0  12.0  2280.0
# 418  SPB-24467  2019-11-15 21:55    152  ...   1.0  10.0  1180.0
# 419  SPB-17570  2019-11-15 22:16    391  ...   5.0  48.0  8100.0
#
# [420 rows x 11 columns]

# %%
lst = df2['대여소번호']

for idx in lst:
  df3 = ReplaceNaN(idx)

df3.isnull().sum()
# Out:
# 자전거번호       0
# 대여일시        0
# 대여소번호       0
# 대여소명        0
# 대여거치대      24
# 반납일시        0
# 반납대여소번호     0
# 반납대여소명      0
# 반납거치대      11
# 이용시간       15
# 이용거리       14
# dtype: int64

# %%
df2['대여소번호'].drop_duplicates()
# Out:
# 0       646
# 4       512
# 7         3
# 20      529
# 25      419
#        ...
# 347     403
# 348     346
# 350     245
# 352     623
# 398    1160
# Name: 대여소번호, Length: 76, dtype: int64
