# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/MyDrive/2022-1-Study_AI/'
# Out:
# /content/drive/MyDrive/2022-1-Study_AI

# %%
# !echo "# 2022-1-Study_AI">>README.md

# %%
# !git init
# !git config --global user.email "sn7679@naver.com"
# !git config --global user.name "cnddlf"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://cnddlf: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@github.com/cnddlf/2022-1-Study_AI.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/2022-1-Study_AI/.git/
# On branch main
# Untracked files:
# 	code/
# 	data/
# 	for_github_commit.ipynb
#
# nothing added to commit but untracked files present
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (6/6), 444 bytes | 55.00 KiB/s, done.
# Total 6 (delta 0), reused 0 (delta 0)
# To https://github.com/cnddlf/2022-1-Study_AI.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git remote rm origin

# %%
# !git add .
# !git commit -m "setup"
# !git push
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  create mode 100644 data/cats_and_dogs-20220317T070632Z-001/cats_and_dogs/data/train/dogs/dog.642.jpg
#  create mode 100644 data/cats_and_dogs-20220317T070632Z-001/cats_and_dogs/data/train/dogs/dog.643.jpg
#  create mode 100644 data/cats_and_dogs-20220317T070632Z-001/cats_and_dogs/data/train/dogs/dog.644.jpg
#  create mode 100644 data/cats_and_dogs-20220317T070632Z-001/cats_and_dogs/data/train/dogs/dog.645.jpg
#  create mode 100644 data/cats_and_dogs-20220317T070632Z-001/cats_and_dogs/data/train/dogs/dog.646.jpg
#  create mode 100644 data/cats_and_dogs-20220317T070632Z-001/cats_and_dogs/data/train/dogs/dog.647.jpg
#  create mode 100644 data/cats_and_dogs-20220317T070632Z-001/cats_and_dogs/data/train/dogs/dog.648.jpg
#  create mode 100644 data/cats_and_dogs-20220317T070632Z-001/cats_and_dogs/data/train/dogs/dog.649.jpg
#  create mode 100644 data/cats_and_dogs-20220317T070632Z-001/cats_and_dogs/data/train/dogs/dog.65.jpg
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From https://github.com/cnddlf/2022-1-Study_AI
#    76c5602..32be012  main       -> origin/main
# hint: Waiting for your editor to close the file... error: unable to start editor 'editor'
# Not committing merge; use 'git commit' to complete the merge.

# %%
# !git add .
# !git commit -m "message"
# !git push
